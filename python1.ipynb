# %% [markdown]
# <a href="https://colab.research.google.com/github/shalukashyapofficial/Projects/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Data Engineering")
# Out:
# Hello Data Engineering

# %% [markdown]
# # Data Types
